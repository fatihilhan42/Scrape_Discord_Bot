# %% [markdown]
# ## **CBR/Anime**

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin  # Import urljoin

# Replace 'your_url_here' with the actual URL of the website you want to scrape
url = 'https://www.cbr.com/category/anime/'  # Replace with the actual URL

# Send an HTTP GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find and print the titles, links, and dates of the articles
    article_blocks = soup.find_all('div', class_='w-display-card-content')  # Replace with the actual HTML element and class name
    for block in article_blocks:
        title_element = block.find('h5', class_='display-card-title').find('a')
        title = title_element.text.strip()
        relative_link = title_element['href']  # Get the relative link
        full_link = urljoin(url, relative_link)  # Prepend base URL to relative links
        date_element = block.find('time', class_='display-card-date')['datetime']
        date = date_element.split('T')[0]  # Extract date part from the datetime attribute
        print(f"Title: {title}")
        print(f"Link: {full_link}")  # Use the full link with the base URL
        print(f"Date: {date}")
        print()  # Add an empty line for better readability
else:
    print('Failed to retrieve the webpage. Status code:', response.status_code)
# Out:
# Title: Dragon Ball: Every Eternal Dragon, Ranked by Coolness
# Link: https://www.cbr.com/dragon-ball-eternal-dragons-ranked/
# Date: 2023-09-23
#
# Title: Boruto: Two Blue Vortex Confirms [Spoiler] Is Darker — And It May Be Sasuke's Fault
# Link: https://www.cbr.com/boruto-two-blue-vortex-sasuke-dark-mentorship-kill-code/
# Date: 2023-09-23
#
# Title: Every Bleach Filler Arc (In Chronological Order)
# Link: https://www.cbr.com/bleach-anime-filler-arc-chronological-order/
# Date: 2023-09-23
#
# Title: 10 Most Powerful Anime Dragons of All Time, Ranked
# Link: https://www.cbr.com/strongest-anime-dragons-ranked/
# Date: 2023-09-23
#
# Title: Saint Seiya: Where the Spin-Offs Fit in the Timeline Chronologically
# Link: https://www.cbr.com/saint-seiya-where-spin-offs-fit-chronologically/
# Date: 2023-09-23
#
# Title: Lupin III Universe Expands Further With Kabuki Stage Play
# Link: https://www.cbr.com/lupin-iii-kabuki-stage-play-announced/
# Date: 2023-09-23
#
# Title: 10 Dragon Ball Details That Don't Make Sense Anymore Because Of Super
# Link: https://www.cbr.com/dragon-ball-details-confusing-because-of-super/
# Date: 2023-09-23
#
# Title: Bleach: Ichigo Kurosaki's Unusual Family Tree Explains His Power
# Link: https://www.cbr.com/bleach-kurosaki-family-tree-explained/
# Date: 2023-09-22
#
# Title: 10 Ways Demon Slayer's Best Characters Could Get Even Stronger
# Link: https://www.cbr.com/how-demon-slayer-best-characters-improve-strength/
# Date: 2023-09-22
#
# Title: Bleach: Mayuri's Four Arrancars, Explained
# Link: https://www.cbr.com/bleach-mayuri-four-arrancars-explained/
# Date: 2023-09-22
#
# Title: Mr. Villain's Day Off Releases New Trailer
# Link: https://www.cbr.com/mr-villains-day-off-trailer/
# Date: 2023-09-22
#
# Title: 10 Best Fantasy Tropes In Berserk, Ranked
# Link: https://www.cbr.com/berserk-classic-fantasy-tropes-ranked/
# Date: 2023-09-22
#
# Title: The Surprising Anime That Inspired Demon Slayer
# Link: https://www.cbr.com/how-jjba-inspired-demon-slayer/
# Date: 2023-09-22
#
# Title: All 9 Blades Wielded By Roronoa Zoro In One Piece
# Link: https://www.cbr.com/one-piece-blades-roronoa-zoro-wielded-used/
# Date: 2023-09-22
#
# Title: 10 Shonen Anime With the Best Stories & Writing, Ranked
# Link: https://www.cbr.com/shonen-anime-best-stories-writing-ranked/
# Date: 2023-09-22
#
# Title: Every Naruto Filler Arc (& Which Episodes To Skip)
# Link: https://www.cbr.com/naruto-every-filler-arc-anime-episodes-skip/
# Date: 2023-09-22
#
# Title: Mushoku Tensei Season 2 Episode 12 Drops Preview Images
# Link: https://www.cbr.com/mushoku-tensei-preview-images/
# Date: 2023-09-22
#
# Title: 10 Things You Didn't Know About Yuki Suetsugu, The Creator Of Chihayafuru
# Link: https://www.cbr.com/yuki-suetsugu-chihayafuru-creator-trivia-fun-facts/
# Date: 2023-09-22
#
# Title: 10 Biggest Anime Time Skips That Changed Everything, Ranked
# Link: https://www.cbr.com/game-changing-anime-time-skips/
# Date: 2023-09-22
#
# Title: Homura Embraces Her Devilish Side in New Puella Magi Madoka Magica the Movie -Rebellion- Collectible
# Link: https://www.cbr.com/homura-puella-magi-madoka-magica-figurine/
# Date: 2023-09-22
