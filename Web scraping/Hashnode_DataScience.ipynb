# %% [markdown]
# ## **Hashnode**

# %%
import requests
from bs4 import BeautifulSoup

# Replace 'your_url_here' with the actual URL of the website you want to scrape
url = 'https://hashnode.com/n/data-science'  # Replace with the actual URL

# Send an HTTP GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find and print the post titles, URLs, and dates
    post_sections = soup.find_all('section', class_='flex flex-col gap-2 sm:gap-4')  # Replace with the actual HTML element and class name
    for section in post_sections:
        title_element = section.find('h1', class_='font-heading text-base sm:text-xl font-semibold sm:font-bold text-slate-700 dark:text-slate-200 hn-break-words cursor-pointer')
        title = title_element.text.strip()
        link_element = title_element.find_parent('a', href=True)
        link = link_element['href']
        date_element = section.find('p', class_='text-sm text-slate-500 dark:text-slate-400 font-normal')
        date = date_element.text.strip()
        print(f"Title: {title}")
        print(f"Link: {link}")
        print(f"Date: {date}")
        print()  # Add an empty line for better readability
else:
    print('Failed to retrieve the webpage. Status code:', response.status_code)
# Out:
# Title: LongLoRA: A New, More Efficient Way to Fine-Tune LLMs
# Link: https://mikeyoung44.hashnode.dev/longlora-a-new-more-efficient-way-to-fine-tune-llms
# Date: 18 hours ago
#
# Title: Bringing Still Pictures to Life with Neural Motion Textures
# Link: https://mikeyoung44.hashnode.dev/bringing-still-pictures-to-life-with-neural-motion-textures
# Date: 18 hours ago
#
# Title: Why Kafka Is the New Data Lake?
# Link: https://risingwavelabs.hashnode.dev/why-kafka-is-the-new-data-lake
# Date: Sep 22, 2023
#
# Title: "DPLYR" -The Data Manipulator
# Link: https://timiranalyst.hashnode.dev/dplyr-the-data-manipulator
# Date: Sep 22, 2023
#
# Title: How to Create Stunning Charts with Matplotlib
# Link: https://edetjoseph.hashnode.dev/how-to-create-stunning-charts-with-matplotlib
# Date: Sep 21, 2023
#
# Title: Data Structures using Python
# Link: https://tomandjerry-blogs.hashnode.dev/data-structures-using-python
# Date: Sep 21, 2023
#
# Title: The Matrix Is Everywhere: Linear Algebra Concepts Relevant to Computer Science
# Link: https://scrappedscript.com/the-matrix-is-everywhere-linear-algebra-concepts-relevant-to-computer-science
# Date: Sep 21, 2023
#
# Title: Streaming Databases: Everything You Wanted to Know
# Link: https://risingwavelabs.hashnode.dev/streaming-databases-everything-you-wanted-to-know
# Date: Sep 21, 2023
#
# Title: Data Engineering vs Data Science
# Link: https://anujsyal.com/data-engineering-vs-data-science
# Date: Sep 21, 2023
#
# Title: Sql For Data Analytics
# Link: https://ishiomaubah.hashnode.dev/sql-for-data-analytics
# Date: Sep 21, 2023
