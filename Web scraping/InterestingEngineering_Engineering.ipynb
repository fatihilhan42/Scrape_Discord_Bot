# %% [markdown]
# ## **Interesting Engineering/ Engineering**

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Base URL to prepend to relative links
base_url = 'https://interestingengineering.com/'

# Replace 'your_url_here' with the actual URL of the website you want to scrape
url = 'https://interestingengineering.com/news/page/1'  # Replace with the actual URL

# Send an HTTP GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find and print the article titles, URLs, and date information
    article_blocks = soup.find_all('div', class_='Category_result__description__iz_rw')  # Replace with the actual HTML element and class name
    for block in article_blocks:
        title_link_element = block.find('a', href=True)
        title = title_link_element.find('h2', class_='Category_result__header__HQgVv').text.strip()
        link = urljoin(base_url, title_link_element['href'])  # Prepend base URL to relative links
        author_element = block.find('a', class_='Category_result__author__name__In7jd')
        author = author_element.text.strip()
        date_element = block.find('span', class_='Category_result__author__publishTime__nwLBU')
        date = date_element.text.strip()
        print(f"Title: {title}")
        print(f"Link: {link}")
        print(f"Author: {author}")
        print(f"Date: {date}")
        print()  # Add an empty line for better readability
else:
    print('Failed to retrieve the webpage. Status code:', response.status_code)
# Out:
# Title: Skeletal remains found uncover ritual and funerary secrets
# Link: https://interestingengineering.com/science/skeletal-remains-found-uncover-ritual-and-funerary-secrets
# Author: Amal Jos Chacko
# Date: just now
#
# Title: Wind power tech could unlock 80% more energy in the US
# Link: https://interestingengineering.com/innovation/wind-power-tech-could-unlock-80-more-energy-in-the-us
# Author: Loukia Papadopoulos
# Date: 1 hour ago
#
# Title: Miracle or not? Magnetized sand flows uphill against gravity
# Link: https://interestingengineering.com/science/miracle-or-not-magnetized-sand-flows-uphill-against-gravity
# Author: Amal Jos Chacko
# Date: 2 hours ago
#
# Title: Android 14 Beta now lets you use your phone as a PC webcam
# Link: https://interestingengineering.com/innovation/android-14-beta-now-lets-you-use-your-phone-as-a-pc-webcam
# Author: Rizwan Choudhury
# Date: 2 hours ago
#
# Title: Canadian telecom uses AI cameras to fight wildfires
# Link: https://interestingengineering.com/innovation/canadian-telecom-uses-ai-cameras-to-fight-wildfires
# Author: Loukia Papadopoulos
# Date: 17 hours ago
#
# Title: Solar cars can reduce global charging needs by half
# Link: https://interestingengineering.com/innovation/solar-cars-can-reduce-global-charging-needs-by-half
# Author: Loukia Papadopoulos
# Date: 17 hours ago
#
# Title: Gold nanoclusters could be the key to hydrogen energy
# Link: https://interestingengineering.com/innovation/gold-nanoclusters-could-be-the-key-to-hydrogen-energy
# Author: Loukia Papadopoulos
# Date: 18 hours ago
#
# Title: Honda releases its first-ever series production V8 engine
# Link: https://interestingengineering.com/transportation/honda-releases-its-first-ever-series-production-v8-engine
# Author: Jijo Malayil
# Date: 19 hours ago
#
# Title: How a student invented an affordable fire-fighting robot
# Link: https://interestingengineering.com/innovation/student-invented-affordable-fire-fighting-robot
# Author: Rizwan Choudhury
# Date: 20 hours ago
