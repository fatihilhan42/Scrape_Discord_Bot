# %% [markdown]
# # **TechCrunch**

# %%
import requests
from bs4 import BeautifulSoup

# Replace 'your_url_here' with the actual URL of the website you want to scrape
url = 'https://techcrunch.com/category/startups/'

# Send an HTTP GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find and print the titles, links, and dates of the blog posts
    post_blocks = soup.find_all('div', class_='post-block')  # Replace with the actual HTML element and class name
    for block in post_blocks:
        title = block.find('h2', class_='post-block__title').text.strip()
        link = block.find('a', class_='post-block__title__link')['href']
        date_element = block.find('time')
        date = date_element.text  # Extract date part from the datetime attribute
        print(f"Title: {title}")
        print(f"Link: {link}")
        print(f"Date: {date}")
        print()  # Add an empty line for better readability
else:
    print('Failed to retrieve the webpage. Status code:', response.status_code)
# Out:
# Title: Bay Area baby belly beholding Battlefield bounty
# Link: https://techcrunch.com/2023/09/22/bay-area-baby-belly-beholding-battlefield-bounty/
# Date:
# 		Sep 22, 2023
#
# Title: Pitch Deck Teardown: Transcend’s $20M Series B deck
# Link: https://techcrunch.com/2023/09/22/sample-series-b-pitch-deck-transcend/
# Date:
# 		Sep 22, 2023
#
# Title: TechCrunch+ Roundup: Prompt engineering, web3 gaming survey, how to spend $10K on paid ads
# Link: https://techcrunch.com/2023/09/22/techcrunch-roundup-prompt-engineering-web3-gaming-survey-how-to-spend-10k-on-paid-ads/
# Date:
# 		Sep 22, 2023
#
# Title: South Africa’s FinanceGPT simplifies financial analysis, set to interface in local languages
# Link: https://techcrunch.com/2023/09/22/financegpt-generative-ai-tools-for-financial-analysis/
# Date:
# 		Sep 22, 2023
#
# Title: HME Square aims to measure glucose painlessly with photoacoustics
# Link: https://techcrunch.com/2023/09/21/hme-square-aims-to-measure-glucose-painlessly-with-photoacoustics/
# Date:
# 		Sep 21, 2023
#
# Title: Communia hopes to build a digital safe space for women
# Link: https://techcrunch.com/2023/09/21/communia-hopes-to-build-a-digital-safe-space-for-women/
# Date:
# 		Sep 21, 2023
#
# Title: And the winner of Startup Battlefield at Disrupt 2023 is . . . BioticsAI
# Link: https://techcrunch.com/2023/09/21/startup-battlefield-winner-techcrunch-disrupt-2023/
# Date:
# 		Sep 21, 2023
#
# Title: Inside Kinhub’s plan to democratize employee wellness
# Link: https://techcrunch.com/2023/09/21/inside-kinhubs-plan-to-democratize-employee-wellness/
# Date:
# 		Sep 21, 2023
#
# Title: eStreamly blends physical, digital shopping with the video as the star
# Link: https://techcrunch.com/2023/09/21/estreamly-livestream-shopping-battlefield/
# Date:
# 		Sep 21, 2023
#
# Title: AvantGuard wants to turn chlorine into the best antiseptic you’ve ever seen
# Link: https://techcrunch.com/2023/09/21/avantguard-chlorine-antiseptic-battlefield/
# Date:
# 		Sep 21, 2023
#
# Title: Don’t want that commuter stipend? Bundl enables employees to choose their own company benefits
# Link: https://techcrunch.com/2023/09/21/bundl-employee-benefits-battlefield/
# Date:
# 		Sep 21, 2023
#
# Title: AppCyclers wants to fight e-waste pollution across Africa
# Link: https://techcrunch.com/2023/09/21/appcyclers-wants-to-fight-e-waste-pollution-across-africa/
# Date:
# 		Sep 21, 2023
#
# Title: Qruise wants to build AI to automate quantum device development
# Link: https://techcrunch.com/2023/09/21/qruise-wants-to-build-ai-to-automate-quantum-device-development/
# Date:
# 		Sep 21, 2023
#
# Title: Artifact co-founder Kevin Systrom doesn’t believe in AI doomerism
# Link: https://techcrunch.com/2023/09/21/artifact-co-founder-kevin-systrom-doesnt-believe-in-ai-doomerism/
# Date:
# 		Sep 21, 2023
#
# Title: Secoda secures $14M to expand its data cataloging platform
# Link: https://techcrunch.com/2023/09/21/secoda-secures-16m-to-expand-its-data-cataloging-platform/
# Date:
# 		Sep 21, 2023
#
# Title: Banish cumulative graphs from your pitch deck
# Link: https://techcrunch.com/2023/09/21/no-cumulative-numbers/
# Date:
# 		Sep 21, 2023
#
# Title: Frontier Space Technologies is developing an on-orbit autonomous lab to make space science easy
# Link: https://techcrunch.com/2023/09/21/frontier-space-technologies-is-developing-an-on-orbit-autonomous-lab-to-make-space-science-easy/
# Date:
# 		Sep 21, 2023
#
# Title: How to spend your first $10K on paid ads
# Link: https://techcrunch.com/2023/09/21/how-to-spend-your-first-10k-on-paid-ads/
# Date:
# 		Sep 21, 2023
#
# Title: Mesh, which helps people manage their digital assets, raises $22M
# Link: https://techcrunch.com/2023/09/21/mesh-which-helps-people-manage-their-digital-assets-raises-22m/
# Date:
# 		Sep 21, 2023
#
# Title: Here are the 6 finalists of Startup Battlefield at Disrupt 2023
# Link: https://techcrunch.com/2023/09/20/here-are-the-6-finalists-of-startup-battlefield-at-disrupt-2023/
# Date:
# 		Sep 20, 2023
