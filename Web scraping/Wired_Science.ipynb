# %% [markdown]
# ## **Wired/Science**

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin  # Import urljoin

# Replace 'your_url_here' with the actual URL of the website you want to scrape
url = 'https://www.wired.com/category/science/'  # Replace with the actual URL

# Send an HTTP GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find and print the article titles, URLs, and categories
    article_blocks = soup.find_all('div', class_='SummaryItemContent-eiDYMl')  # Replace with the actual HTML element and class name
    for block in article_blocks:
        title_element = block.find('h3', class_='SummaryItemHedBase-hiFYpQ')
        title = title_element.text.strip()
        relative_link = block.find('a', class_='SummaryItemHedLink-civMjp')['href']  # Get the relative link
        full_link = urljoin(url, relative_link)  # Prepend base URL to relative links
        category_element = block.find('span', class_='RubricName-fVtemz')
        category = category_element.text.strip() if category_element else "N/A"  # Handle missing category
        print(f"Title: {title}")
        print(f"Link: {full_link}")  # Use the full link with the base URL
        print(f"Category: {category}")
        print()  # Add an empty line for better readability
else:
    print('Failed to retrieve the webpage. Status code:', response.status_code)
# Out:
# Title: The World’s Largest—and Stinkiest—Flower Is in Danger of Extinction
# Link: https://www.wired.com/story/the-worlds-largest-and-stinkiest-flower-is-in-danger-of-extinction/
# Category: Smell You Later
#
# Title: Behold the Latest Treasures Unearthed at Mexico City's Templo Mayor
# Link: https://www.wired.com/story/archaeology-treasures-offerings-mexico-city-templo-mayor/
# Category: Archaeology
#
# Title: Inside the Race to Stop a Deadly Viral Outbreak in India
# Link: https://www.wired.com/story/kerala-nipah-outbreak/
# Category: Epidemics
#
# Title: A Medieval French Skeleton Is Rewriting the History of Syphilis
# Link: https://www.wired.com/story/a-medieval-french-skeleton-is-rewriting-the-history-of-syphilis/
# Category: N/A
#
# Title: Everything You Need to Know About Getting Your Genome Sequenced
# Link: https://www.wired.com/story/everything-you-need-to-know-about-getting-your-genome-sequenced/
# Category: N/A
#
# Title: High Blood Pressure Is the World’s Biggest Killer. Now There’s a Plan to Tackle It
# Link: https://www.wired.com/story/high-blood-pressure-is-the-worlds-biggest-killer-now-theres-a-plan-to-tackle-it/
# Category: N/A
#
# Title: DeepMind’s New AI Can Predict Genetic Diseases
# Link: https://www.wired.com/story/deepmind-ai-alphamissense-genetics-rare-diseases/
# Category: N/A
#
# Title: NASA’s OSIRIS-REx Is About to Bring Asteroid Pieces Back to Earth
# Link: https://www.wired.com/story/nasas-osiris-rex-is-about-to-bring-asteroid-pieces-back-to-earth/
# Category: N/A
#
# Title: The Dumb Alien Mummy Story Takes an Entirely Predictable Turn
# Link: https://www.wired.com/story/mexico-fake-aliens-science-fightback/
# Category: N/A
#
# Title: A Pair of Sun Probes Just Got Closer to Solving a Solar Enigma
# Link: https://www.wired.com/story/a-pair-of-sun-probes-just-got-closer-to-solving-a-solar-enigma/
# Category: N/A
#
# Title: NASA Didn’t Find Aliens—but if You See Any UFOs, Holler
# Link: https://www.wired.com/story/nasa-ufos-aliens-report-2023/
# Category: N/A
#
# Title: Explore the Ancient Aztec Capital in This Lifelike 3D Rendering
# Link: https://www.wired.com/story/explore-tenochtitlan-ancient-aztec-capital-3d-render-thomas-kole/
# Category: N/A
#
# Title: This Treaty Could Stop Plastic Pollution—or Doom the Earth to Drown in It
# Link: https://www.wired.com/story/this-treaty-could-stop-plastic-pollution-or-doom-the-earth-to-drown-in-it/
# Category: N/A
#
# Title: Why Some Animals Thrive in Cities
# Link: https://www.wired.com/story/urban-animals-wildlife-biodiversity-traits-pigeons-reptiles-amphibians/
# Category: N/A
#
# Title: In a Fierce Desert, Microbe ‘Crusts’ Show How Life Tamed the Land
# Link: https://www.wired.com/story/in-a-fierce-desert-microbe-crusts-show-how-life-tamed-the-land/
# Category: N/A
#
# Title: The US Is Mobilizing an Army to Fight the Climate Crisis
# Link: https://www.wired.com/story/the-us-is-mobilizing-an-army-to-fight-the-climate-crisis/
# Category: N/A
#
# Title: The UK Is Burning Climate Pledges to Fuel a Culture War
# Link: https://www.wired.com/story/uk-net-zero-climate-pledges-weakened-rishi-sunak/
# Category: N/A
#
# Title: The Mysterious 'Warming Hole' in the Middle of the US
# Link: https://www.wired.com/story/the-mysterious-warming-hole-in-the-middle-of-the-us/
# Category: N/A
#
# Title: Ski Resorts Are Giving Up on Snow
# Link: https://www.wired.com/story/ski-adaptations-climate-change-paganella-italy/
# Category: N/A
#
# Title: Radiation Is Everywhere. But It’s Not All Bad
# Link: https://www.wired.com/story/radiation-is-everywhere-but-its-not-all-bad/
# Category: N/A
#
# Title: Electrifying Your Home Is About to Get a Lot Cheaper
# Link: https://www.wired.com/story/electrifying-your-home-is-about-to-get-a-lot-cheaper/
# Category: N/A
#
# Title: Your New Apple Watch Won’t Be Carbon Neutral
# Link: https://www.wired.com/story/new-apple-watch-series-9-wont-be-carbon-neutral/
# Category: N/A
#
# Title: Big Batteries Are Booming. So Are Fears They'll Catch Fire
# Link: https://www.wired.com/story/big-grid-batteries-are-booming-so-are-fears-fire/
# Category: N/A
#
# Title: A New Proof Moves the Needle on a Sticky Geometry Problem
# Link: https://www.wired.com/story/a-new-proof-moves-the-needle-on-a-sticky-geometry-problem/
# Category: N/A
#
# Title: A New Map of the Universe, Painted With Cosmic Neutrinos
# Link: https://www.wired.com/story/cosmic-neutrinos-origin/
# Category: N/A
#
# Title: How to Cool an Object Without Using Any Energy
# Link: https://www.wired.com/story/how-to-cool-an-object-without-using-any-energy/
# Category: N/A
#
# Title: The Lawlessness of Large Numbers
# Link: https://www.wired.com/story/the-lawlessness-of-large-numbers/
# Category: N/A
#
# Title: The Gruesome Story of How Neuralink’s Monkeys Actually Died
# Link: https://www.wired.com/story/elon-musk-pcrm-neuralink-monkey-deaths/
# Category: N/A
#
# Title: Everything We Know About Neuralink’s Brain Implant Trial
# Link: https://www.wired.com/story/everything-we-know-about-neuralinks-brain-implant-trial/
# Category: N/A
#
# Title: Here Come the Glow-in-the-Dark Houseplants
# Link: https://www.wired.com/story/here-come-the-glow-in-the-dark-houseplants/
# Category: N/A
#
# Title: Crispr Pioneer Jennifer Doudna Has the Guts to Take On the Microbiome
# Link: https://www.wired.com/story/crispr-jennifer-doudna-microbiome/
# Category: N/A
#
# Title: AI Is Building Highly Effective Antibodies That Humans Can’t Even Imagine
# Link: https://www.wired.com/story/labgenius-antibody-factory-machine-learning/
# Category: N/A
#
# Title: This Artificial Muscle Moves Stuff on Its Own
# Link: https://www.wired.com/story/this-artificial-muscle-moves-stuff-on-its-own/
# Category: N/A
#
# Title: Get Ready for 3D-Printed Organs and a Knife That ‘Smells’ Tumors
# Link: https://www.wired.com/story/medical-innovations-hospital-future/
# Category: N/A
#
# Title: Rovers Are So Yesterday. It’s Time to Send a Snakebot to Space
# Link: https://www.wired.com/story/rovers-are-so-yesterday-its-time-to-send-a-snakebot-to-space/
# Category: N/A
#
# Title: Is It Real or Imagined? Here’s How Your Brain Tells the Difference
# Link: https://www.wired.com/story/is-it-real-or-imagined-heres-how-your-brain-tells-the-difference/
# Category: N/A
#
# Title: Brain Implants That Help Paralyzed People Speak Just Broke New Records
# Link: https://www.wired.com/story/brain-implants-that-help-paralyzed-people-speak-just-broke-new-records/
# Category: N/A
#
# Title: Use of AI Is Seeping Into Academic Journals—and It’s Proving Difficult to Detect
# Link: https://www.wired.com/story/use-of-ai-is-seeping-into-academic-journals-and-its-proving-difficult-to-detect/
# Category: N/A
#
# Title: Everyone Was Wrong About Antipsychotics
# Link: https://www.wired.com/story/everyone-was-wrong-about-antipsychotics/
# Category: N/A
#
# Title: A Global Surge in Cholera Outbreaks May Be Fueled by Climate Change
# Link: https://www.wired.com/story/a-global-surge-in-cholera-outbreaks-may-be-fueled-by-climate-change/
# Category: Public Health
#
# Title: This Is Your Kid’s Brain on Extreme Heat
# Link: https://www.wired.com/story/extreme-heat-kids-schools-learning/
# Category: Any Questions?
#
# Title: Insiders Reveal Major Problems at Lab-Grown-Meat Startup Upside Foods
# Link: https://www.wired.com/story/upside-foods-lab-grown-chicken/
# Category: Fake Meat
#
# Title: Libya’s Deadly Floods Show the Growing Threat of Medicanes
# Link: https://www.wired.com/story/libya-medicane-flooding-storm-daniel-derma/
# Category: Climate Crisis
#
# Title: No, This Is Not an Alien. Here’s Why
# Link: https://www.wired.com/story/mexico-congress-aliens-fake/
# Category: Phone Home
#
# Title: Scientists Say You’re Looking for Alien Civilizations All Wrong
# Link: https://www.wired.com/story/scientists-say-youre-looking-for-alien-civilizations-all-wrong/
# Category: Search Party
#
# Title: Covid Boosters Can’t Outpace New Mutations. Here’s Why They Still Work
# Link: https://www.wired.com/story/covid-vaccine-boosters-2023-moderna-pfizer/
# Category: Public Health
#
# Title: Serious Brain Trauma Starts Well Before Young Athletes Go Pro
# Link: https://www.wired.com/story/serious-brain-trauma-starts-well-before-young-athletes-go-pro/
# Category: Public Health
#
# Title: Yes, There’s a New Covid Variant. No, You Shouldn’t Panic
# Link: https://www.wired.com/story/pirola-covid-variant/
# Category: Public Health
#
# Title: Rivers Are Drowning in Toxic Sludge
# Link: https://www.wired.com/story/blue-green-algae-is-filling-rivers-with-toxic-sludge/
# Category: Growth Spurt
#
# Title: A Summer of Record Heat Deals Costly Damage to Texas Water Systems
# Link: https://www.wired.com/story/a-summer-of-record-heat-deals-costly-damage-to-texas-water-systems/
# Category: Hot Button
#
# Title: SpaceX Must Fix 63 Issues Before Its Starship Can Fly Again
# Link: https://www.wired.com/story/the-investigation-of-spacexs-starship-explosion-is-complete-and-elon-musk-has-more-work-to-do/
# Category: Grounded
#
# Title: The Rapid Intensification of Hurricane Lee Is a Warning
# Link: https://www.wired.com/story/the-rapid-intensification-of-hurricane-lee-is-a-warning/
# Category: Climate Change
#
# Title: Scientists Just Tried Growing Human Kidneys in Pigs
# Link: https://www.wired.com/story/scientists-just-tried-growing-human-kidneys-in-pigs/
# Category: Building Blocks
#
# Title: A Flesh-Eating Bacterium Is Creeping North as Oceans Warm
# Link: https://www.wired.com/story/a-flesh-eating-bacterium-is-creeping-north-as-oceans-warm/
# Category: Public Health
#
# Title: Ozempic and Wegovy Can Also Protect Your Heart
# Link: https://www.wired.com/story/weight-loss-drugs-ozempic-and-wegovy-can-also-protect-the-heart/
# Category: Public Health
#
# Title: A Billion-Dollar Plan to Fix Farm Emissions Might Make Things Worse
# Link: https://www.wired.com/story/usda-climate-smart-agriculture/
# Category: Seeds of Doubt
#
# Title: Climate Change Has Finally Come for Burning Man
# Link: https://www.wired.com/story/climate-change-has-finally-come-for-burning-man/
# Category: Drowning Man
#
# Title: 7 Face Masks Your Kids May Actually Wear
# Link: https://www.wired.com/gallery/best-kids-face-masks/
# Category: Buying Guide
#
# Title: What Ever Happened to the Tiny House Movement?
# Link: https://www.wired.com/story/what-ever-happened-to-the-tiny-house-movement/
# Category: Dream Small
